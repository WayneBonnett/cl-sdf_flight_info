# %%
#include the necessary libs
import pandas as pd
import matplotlib 
from matplotlib import pyplot as plt

#open the arrival and departures .csv files
arrivals = pd.read_csv('./assets/arrivals.csv', usecols=['airline', 'arr_year', 'total_arrivals'])
departures = pd.read_csv('./assets/departures.csv', usecols=['airline', 'dep_year', 'total_departures'])

# %%
#View some of the arrival data to verify it has loaded properly.
print(arrivals.head(10))
print(arrivals.info())
print(arrivals.shape)
# Out:
#              airline  arr_year  total_arrivals
# 0      Allegiant Air      2018             906
# 1      Allegiant Air      2019             840
# 2      Allegiant Air      2020             729
# 3      Allegiant Air      2021             928
# 4      Allegiant Air      2022             753
# 5  American Airlines      2018              28
# 6  American Airlines      2019             845
# 7  American Airlines      2020             172
# 8  American Airlines      2021             143
# 9  American Airlines      2022             699
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   airline         30 non-null     object
#  1   arr_year        30 non-null     int64
#  2   total_arrivals  30 non-null     int64
# dtypes: int64(2), object(1)
# memory usage: 848.0+ bytes
# None
# (30, 3)

# %%
#View some of the departure data to verify it has loaded properly.
print(departures.head(10))
print(departures.info())
print(departures.shape)
# Out:
#              airline  dep_year  total_departures
# 0      Allegiant Air      2018               906
# 1      Allegiant Air      2019               840
# 2      Allegiant Air      2020               729
# 3      Allegiant Air      2021               932
# 4      Allegiant Air      2022               754
# 5  American Airlines      2018                28
# 6  American Airlines      2019               845
# 7  American Airlines      2020               172
# 8  American Airlines      2021               143
# 9  American Airlines      2022               697
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 3 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   airline           30 non-null     object
#  1   dep_year          30 non-null     int64
#  2   total_departures  30 non-null     int64
# dtypes: int64(2), object(1)
# memory usage: 848.0+ bytes
# None
# (30, 3)

# %%
#plot the arrival data
arrivals['arr_year'] = arrivals['arr_year'].astype(int)
arrivals.groupby(['arr_year', 'airline']).sum()['total_arrivals'].unstack().plot(kind='line', ylabel='# of flights')
plt.xticks(arrivals['arr_year'].unique())
plt.xlabel('Year')
plt.title('Total SDF arrivals by Year')
plt.show()

# %%
#plot the departure data
departures['dep_year'] = departures['dep_year'].astype(int)
departures.groupby(['dep_year', 'airline']).sum()['total_departures'].unstack().plot(kind='line', ylabel='Total flights')
plt.xticks(departures['dep_year'].unique())
plt.xlabel('Year')
plt.title('Total SDF Departures by Year')
plt.show()
